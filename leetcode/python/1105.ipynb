# %%
def minHeightShelves(books, shelfWidth):
    # books = [[thickness, height]]
    n = len(books)
    dp = [0] * (n+1)

    for i in range(n):
        # for current book
        # it can be placed in a new layer alone
        # or with books before together if possible
        dp[i+1] = dp[i] + books[i][1] # a new line
        curWidth = books[i][0]
        curH = books[i][1]
        for j in range(i-1, -1, -1):
            curWidth += books[j][0]
            if curWidth > shelfWidth:
                break
            curH = max(curH, books[j][1])
            dp[i+1] = min(dp[i+1], dp[j] + curH)
        
    print(dp)
    print(dp[-1])

    
books = [[1,1],[2,3],[2,3],[1,1],[1,1],[1,1],[1,2]]
shelfWidth = 4

books = [[1,3],[2,4],[3,2]]
shelfWidth = 6

books = [[11,83],[170,4],[93,80],[155,163],[134,118],[75,14],[122,192],[123,154],[187,29],[160,64],[170,152],[113,179],[60,102],[28,187],[59,95],[187,97],[49,193],[67,126],[75,45],[130,160],[4,102],[116,171],[43,170],[96,188],[54,15],[167,183],[58,158],[59,55],[148,183],[89,95],[90,113],[51,49],[91,28],[172,103],[173,3],[131,78],[11,199],[77,200],[58,65],[77,30],[157,58],[18,194],[101,148],[22,197],[76,181],[21,176],[50,45],[80,174],[116,198],[138,9],[58,125],[163,102],[133,175],[21,39],[141,156],[34,185],[14,113],[11,34],[35,184],[16,132],[78,147],[85,170],[32,149],[46,94],[196,3],[155,90],[9,114],[117,119],[17,157],[94,178],[53,55],[103,142],[70,121],[9,141],[16,170],[92,137],[157,30],[94,82],[144,149],[128,160],[8,147],[153,198],[12,22],[140,68],[64,172],[86,63],[66,158],[23,15],[120,99],[27,165],[79,174],[46,19],[60,98],[160,172],[128,184],[63,172],[135,54],[40,4],[102,171],[29,125],[81,9],[111,197],[16,90],[22,150],[168,126],[187,61],[47,190],[54,110],[106,102],[55,47],[117,134],[33,107],[2,10],[18,62],[109,188],[113,37],[59,159],[120,175],[17,147],[112,195],[177,53],[148,173],[29,105],[196,32],[123,51],[29,19],[161,178],[148,2],[70,124],[126,9],[105,87],[41,121],[147,10],[78,167],[91,197],[22,98],[73,33],[148,194],[166,64],[33,138],[139,158],[160,19],[140,27],[103,109],[88,16],[99,181],[2,140],[50,188],[200,77],[73,84],[159,130],[115,199],[152,79],[1,172],[124,136],[117,138],[158,86],[193,150],[56,57],[150,133],[52,186],[21,145],[127,97],[108,110],[174,44],[199,169],[139,200],[66,48],[52,190],[27,86],[142,191],[191,79],[126,114],[125,100],[176,95],[104,79],[146,189],[144,78],[52,106],[74,74],[163,128],[34,181],[20,178],[15,107],[105,8],[66,142],[39,126],[95,59],[164,69],[138,18],[110,145],[128,200],[149,150],[149,93],[145,140],[90,170],[81,127],[57,151],[167,127],[95,89]]
shelfWidth = 200


minHeightShelves(books, shelfWidth)
# Out:
# [0, 83, 83, 163, 326, 444, 458, 636, 790, 819, 883, 1035, 1214, 1214, 1401, 1401, 1498, 1691, 1691, 1691, 1851, 1851, 2022, 2022, 2210, 2210, 2393, 2551, 2551, 2734, 2829, 2847, 2896, 2896, 2999, 3002, 3080, 3201, 3280, 3280, 3310, 3368, 3504, 3562, 3565, 3701, 3746, 3746, 3877, 3944, 3953, 4069, 4171, 4346, 4346, 4502, 4531, 4531, 4531, 4687, 4687, 4687, 4857, 4857, 4857, 4860, 4950, 4974, 5069, 5107, 5247, 5247, 5389, 5389, 5389, 5417, 5554, 5584, 5666, 5815, 5975, 5975, 6173, 6173, 6241, 6413, 6413, 6571, 6571, 6670, 6736, 6844, 6844, 6910, 7082, 7266, 7266, 7320, 7320, 7491, 7491, 7500, 7688, 7697, 7697, 7823, 7884, 8074, 8074, 8176, 8176, 8310, 8310, 8310, 8310, 8498, 8535, 8657, 8710, 8710, 8905, 8958, 9131, 9131, 9163, 9214, 9214, 9392, 9394, 9518, 9518, 9605, 9639, 9649, 9816, 9846, 9846, 9879, 10073, 10137, 10211, 10295, 10314, 10341, 10450, 10450, 10631, 10631, 10638, 10715, 10799, 10929, 11128, 11207, 11300, 11379, 11517, 11603, 11753, 11810, 11943, 12129, 12129, 12129, 12239, 12283, 12452, 12652, 12700, 12842, 12842, 13033, 13112, 13226, 13326, 13421, 13500, 13689, 13767, 13795, 13869, 13997, 14050, 14178, 14178, 14178, 14320, 14320, 14320, 14389, 14407, 14552, 14752, 14902, 14995, 15135, 15305, 15305, 15456, 15583, 15672]
# 15672

# %% [markdown]
# ### first failed editon
# ### check the problem analyz

# %%
def minHeightShelves(books, shelfWidth):
    # books = [[thickness, height]]
    n = len(books)
    dp = [[0, 0, 0] for _ in range(n+1)] # dp[i] = [total h, remain, curH] # h = cur mintotal Height;remain = remaining width of the last layer
    # dp[0] = [books[0][0], shelfWidth - books[0][1]]
    dp[0] = [0, 0, 0]  # dummy, [0 total height, no remain space, 0 curH]

    for i in range(n):
        # dp[i+1] for book i
        if books[i][0] <= dp[i][1]:
            '''
            I think here is the problem. 
            if there are space, and the height of cur book is less than curH, then, we can just append cur book to the layer
            but, if cur book is higher than curH, we append it and already changed the result, so we need to check data before.

            # suppose, shelfWidth is 3, and every book has 1 unit thickness
            # cur book is 9, and current state is as below
            [1,_,_]
            [1,1,9]
            [1,1,1]
            # if we just append cur book to this state
            [1,9,_]
            [1,1,9]
            [1,1,1]

            # we can not consider the following situation
            [9,1,9]
            [1,1,_]
            [1,1,1]

            '''
            # just append cur book to this layer
            curH = max(books[i][1], dp[i][2])
            dp[i+1] = [dp[i][0] + curH - dp[i][2], dp[i][1] - books[i][0], curH]
        else:
            dp[i+1] = [dp[i][0]+books[i][1], shelfWidth-books[i][0], books[i][1]]
            curH = books[i][1]
            curRemain = shelfWidth-books[i][0]
            j = i-1
            while j >= 0 and books[j][0] <= curRemain:
                curRemain -= books[j][0]
                curH = max(curH, books[j][1])
                if dp[j][0] + curH < dp[i+1][0]:
                    dp[i+1] = [dp[j][0] + curH, curRemain, curH]
    
    # print(dp)
    print([dp[i][0] for i in range(len(dp))])
    return dp[-1][0]



books = [[1,1],[2,3],[2,3],[1,1],[1,1],[1,1],[1,2]]
shelfWidth = 4

books = [[1,3],[2,4],[3,2]]
shelfWidth = 6

books = [[11,83],[170,4],[93,80],[155,163],[134,118],[75,14],[122,192],[123,154],[187,29],[160,64],[170,152],[113,179],[60,102],[28,187],[59,95],[187,97],[49,193],[67,126],[75,45],[130,160],[4,102],[116,171],[43,170],[96,188],[54,15],[167,183],[58,158],[59,55],[148,183],[89,95],[90,113],[51,49],[91,28],[172,103],[173,3],[131,78],[11,199],[77,200],[58,65],[77,30],